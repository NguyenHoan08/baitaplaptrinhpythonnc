# %%
import pandas as pd
import numpy as np
s=pd.Series({'a':1.0,'b':2.0,'c':3.0})
print("Series:\n",s)
arr=np.arange(1,10).reshape(3,3)
df= pd.DataFrame(arr, columns=['col1','col2','col3'])
print("\nDataFrame:\n",df)
# Out:
# Series:
#  a    1.0
# b    2.0
# c    3.0
# dtype: float64
#
# DataFrame:
#     col1  col2  col3
# 0     1     2     3
# 1     4     5     6
# 2     7     8     9

# %%
import pandas as pd
data= pd.Series([1.0,0.25,6.0,0.75])
print(data)
# Out:
# 0    1.00
# 1    0.25
# 2    6.00
# 3    0.75
# dtype: float64

# %%
print("chỉ muc (index):",data.index)
# Out:
# chỉ muc (index): RangeIndex(start=0, stop=4, step=1)

# %%
import pandas as pd
population_dict = {'Hà Nội':8330830,
'Quảng Ninh':1358085, 'Nam Định': 1836270,
'Đà Nẵng':1195490,
'TP.Hồ Chí Minh':9411805}
population = pd.Series(population_dict) 
population
# Out:
# Hà Nội            8330830
# Quảng Ninh        1358085
# Nam Định          1836270
# Đà Nẵng           1195490
# TP.Hồ Chí Minh    9411805
# dtype: int64

# %%
area_dict={'Hà Nội':3358.9, 'Quảng Ninh':6177.7,
'Nam Định':1668.0,
'Đà Nẵng':1284.9, 'TP.Hồ Chí Minh':2061.0}
area = pd.Series(area_dict) 
area
# Out:
# Hà Nội            3358.9
# Quảng Ninh        6177.7
# Nam Định          1668.0
# Đà Nẵng           1284.9
# TP.Hồ Chí Minh    2061.0
# dtype: float64

# %%
VietNam = pd.DataFrame({'Dân số':population, 'Diện tích':area}) 
VietNam
# Out:
#                  Dân số  Diện tích
# Hà Nội          8330830     3358.9
# Quảng Ninh      1358085     6177.7
# Nam Định        1836270     1668.0
# Đà Nẵng         1195490     1284.9
# TP.Hồ Chí Minh  9411805     2061.0

# %%
print(f'mangr số liệu dân số:',population.values)
# Out:
# mangr số liệu dân số: [8330830 1358085 1836270 1195490 9411805]

# %%
type(population.values)
# Out:
# numpy.ndarray

# %%
print(population.index)
# Out:
# Index(['Hà Nội', 'Quảng Ninh', 'Nam Định', 'Đà Nẵng', 'TP.Hồ Chí Minh'], dtype='object')

# %%
print(population.name)
# Out:
# None

# %%
population
# Out:
# Hà Nội            8330830
# Quảng Ninh        1358085
# Nam Định          1836270
# Đà Nẵng           1195490
# TP.Hồ Chí Minh    9411805
# dtype: int64

# %%
print("giá trị tại chỉ mục 2:",population[2])
print("\ncac phần tử từ index1 đến 2:")
print(population[1:3])
# Out:
# giá trị tại chỉ mục 2: 1836270
#
# cac phần tử từ index1 đến 2:
# Quảng Ninh    1358085
# Nam Định      1836270
# dtype: int64
# /var/folders/s9/fds8rjtd2wl11pg54pd554wr0000gn/T/ipykernel_87420/3570516050.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print("giá trị tại chỉ mục 2:",population[2])

# %%
print("phần tử:",data.size)
print("kích thước:",data.nbytes)
print("tên:",data.dtype)
print("kiểm tra:",data.base is not None)
# Out:
# phần tử: 4
# kích thước: 32
# tên: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/s9/fds8rjtd2wl11pg54pd554wr0000gn/T/ipykernel_87420/4074116636.py in ?()
#       1 print("phần tử:",data.size)
#       2 print("kích thước:",data.nbytes)
#       3 print("tên:",data.dtype)
# ----> 4 print("kiểm tra:",data.base is not None)
#
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'base'

# %%
import matplotlib.pyplot as plt
population.plot(kind='bar',title='dan so')
plt.ylabel("số người")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
area_dict={'Hà Nội':3358.9, 'Quảng Ninh':6177.7,
'Nam Định':1668.0,
'Đà Nẵng':1284.9, 'TP.Hồ Chí Minh':2061.0}
area = pd.Series(area_dict) 
area
# Out:
# Hà Nội            3358.9
# Quảng Ninh        6177.7
# Nam Định          1668.0
# Đà Nẵng           1284.9
# TP.Hồ Chí Minh    2061.0
# dtype: float64

# %%
VietNam = pd.DataFrame({'Dân số':population, 'Diện tích':area}) 
VietNam
# Out:
#                  Dân số  Diện tích
# Hà Nội          8330830     3358.9
# Quảng Ninh      1358085     6177.7
# Nam Định        1836270     1668.0
# Đà Nẵng         1195490     1284.9
# TP.Hồ Chí Minh  9411805     2061.0

# %%
VietNam.index
# Out:
# Index(['Hà Nội', 'Quảng Ninh', 'Nam Định', 'Đà Nẵng', 'TP.Hồ Chí Minh'], dtype='object')

# %%
VietNam.columns
# Out:
# Index(['Dân số', 'Diện tích'], dtype='object')

# %%
VietNam['Dân số']
# Out:
# Hà Nội            8330830
# Quảng Ninh        1358085
# Nam Định          1836270
# Đà Nẵng           1195490
# TP.Hồ Chí Minh    9411805
# Name: Dân số, dtype: int64

# %%
print('Dân số thủ đô Hà Nội:',VietNam['Dân số']['Hà Nội']) 
print('Dân số thủ đô Hà Nội:',VietNam['Dân số'][0])
# Out:
# Dân số thủ đô Hà Nội: 8330830
# Dân số thủ đô Hà Nội: 8330830
# /var/folders/s9/fds8rjtd2wl11pg54pd554wr0000gn/T/ipykernel_87420/256604589.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Dân số thủ đô Hà Nội:',VietNam['Dân số'][0])

# %%
print('chỉ mục:',df.index)
# Out:
# chỉ mục: RangeIndex(start=0, stop=3, step=1)

# %%
import pandas as pd
ind=pd.Index([2, 3, 6, 7, 11]) 
ind
# Out:
# Index([2, 3, 6, 7, 11], dtype='int64')

# %%
ind[1]
# Out:
# np.int64(3)

# %%
ind[::2]
# Out:
# Index([2, 6, 11], dtype='int64')

# %%
print(ind.size, ind.shape, ind.ndim, ind.dtype)
# Out:
# 5 (5,) 1 int64

# %%
indA=pd.Index([0,2,4,6,8])
indB=pd.Index([1,3,7,8,9])
print('IndexA:',indA)
print('IndexB:',indB)
print('\nhop:',indA.union(indB))
print('hiệu:',indA.difference(indB))
print('giao:',indA.intersection(indB))
print('hiệu đối xứng:',indA.symmetric_difference(indB))
print('\nA thuộc B:',indA.isin(indB))
# Out:
# IndexA: Index([0, 2, 4, 6, 8], dtype='int64')
# IndexB: Index([1, 3, 7, 8, 9], dtype='int64')
#
# hop: Index([0, 1, 2, 3, 4, 6, 7, 8, 9], dtype='int64')
# hiệu: Index([0, 2, 4, 6], dtype='int64')
# giao: Index([8], dtype='int64')
# hiệu đối xứng: Index([0, 1, 2, 3, 4, 6, 7, 9], dtype='int64')
#
# A thuộc B: [False False False False  True]

# %%
import pandas as pd
s=pd.Series([10,20,30])
print(s)
print(s.index)
print(s.iloc[1])
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
# RangeIndex(start=0, stop=3, step=1)
# 20

# %%
import pandas as pd
data = pd.Series([1, 2, 3, 4],
                 index=['a','b','c','d'])
data
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
import pandas as pd
population = pd.Series({'Hà Nội':8330830,
                       'Quảng Ninh':1358490,
                       'Nam Định': 1771000,
                       'Đà Nẵng':1191381,
                       'TP.Hồ Chí Minh':9411805})
area=pd.Series({'Hà Nội':3358.9, 
                'Quảng Ninh':6177.7,
                'Nam Định': 1668.0,
                'Đà Nẵng':1284.9,
                'TP.Hồ Chí Minh':2061.0})
data = pd.DataFrame({'Dân số':population, 'Diện tích':area}) 
data
# Out:
#                  Dân số  Diện tích
# Hà Nội          8330830     3358.9
# Quảng Ninh      1358490     6177.7
# Nam Định        1771000     1668.0
# Đà Nẵng         1191381     1284.9
# TP.Hồ Chí Minh  9411805     2061.0

# %%
data['Dân số']
# Out:
# Hà Nội            8330830
# Quảng Ninh        1358490
# Nam Định          1771000
# Đà Nẵng           1191381
# TP.Hồ Chí Minh    9411805
# Name: Dân số, dtype: int64

# %%
data['population'] = data['Dân số']
print(data)
# Out:
#                  Dân số  Diện tích  population
# Hà Nội          8330830     3358.9     8330830
# Quảng Ninh      1358490     6177.7     1358490
# Nam Định        1771000     1668.0     1771000
# Đà Nẵng         1191381     1284.9     1191381
# TP.Hồ Chí Minh  9411805     2061.0     9411805

# %%
data.population
# Out:
# Hà Nội            8330830
# Quảng Ninh        1358490
# Nam Định          1771000
# Đà Nẵng           1191381
# TP.Hồ Chí Minh    9411805
# Name: population, dtype: int64

# %%
data['Mật độ']=data['Dân số']/data['Diện tích'] 
data
# Out:
#                  Dân số  Diện tích  population       Mật độ
# Hà Nội          8330830     3358.9     8330830  2480.225669
# Quảng Ninh      1358490     6177.7     1358490   219.902229
# Nam Định        1771000     1668.0     1771000  1061.750600
# Đà Nẵng         1191381     1284.9     1191381   927.216904
# TP.Hồ Chí Minh  9411805     2061.0     9411805  4566.620573

# %%
data[0:2]
# Out:
#              Dân số  Diện tích  population       Mật độ
# Hà Nội      8330830     3358.9     8330830  2480.225669
# Quảng Ninh  1358490     6177.7     1358490   219.902229

# %%
data[data['Dân số']>1000000]
# Out:
#                  Dân số  Diện tích  population       Mật độ
# Hà Nội          8330830     3358.9     8330830  2480.225669
# Quảng Ninh      1358490     6177.7     1358490   219.902229
# Nam Định        1771000     1668.0     1771000  1061.750600
# Đà Nẵng         1191381     1284.9     1191381   927.216904
# TP.Hồ Chí Minh  9411805     2061.0     9411805  4566.620573

# %%
#Sử dụng loc
print(data)
#Lấy hàng đầu tiên
print('\n Dữ liệu của Hà Nội:\n',data.loc['Hà Nội'])
#Lấy dữ liệu 3 hàng đầu tiên
print("\n Dữ liệu của Hà Nội, Quảng Ninh và Nam Định:\n",data.loc[:'Nam Định'])
 #Dữ liệu của 2 hàng và 2 cột đầu tiên
print("\nDữ liệu dân số, diện tích của Hà Nội, Quảng Ninh:\n",data.loc[:'Quảng Ninh',:'Diện tích']) 
#Lấy dữ liệu của tất cả các hàng và các cột cuối cùng 
print("\n Mật độ dân số các Tỉnh/Thành phố:\n",data.loc[:,'Mật độ'])
# Out:
#                  Dân số  Diện tích  population       Mật độ
# Hà Nội          8330830     3358.9     8330830  2480.225669
# Quảng Ninh      1358490     6177.7     1358490   219.902229
# Nam Định        1771000     1668.0     1771000  1061.750600
# Đà Nẵng         1191381     1284.9     1191381   927.216904
# TP.Hồ Chí Minh  9411805     2061.0     9411805  4566.620573
#
#  Dữ liệu của Hà Nội:
#  Dân số        8.330830e+06
# Diện tích     3.358900e+03
# population    8.330830e+06
# Mật độ        2.480226e+03
# Name: Hà Nội, dtype: float64
#
#  Dữ liệu của Hà Nội, Quảng Ninh và Nam Định:
#               Dân số  Diện tích  population       Mật độ
# Hà Nội      8330830     3358.9     8330830  2480.225669
# Quảng Ninh  1358490     6177.7     1358490   219.902229
# Nam Định    1771000     1668.0     1771000  1061.750600
#
# Dữ liệu dân số, diện tích của Hà Nội, Quảng Ninh:
#               Dân số  Diện tích
# Hà Nội      8330830     3358.9
# Quảng Ninh  1358490     6177.7
#
# ...

# %%
print(data)
#Lấy hàng đầu tiên
print("\nDữ liệu của thủ đô Hà Nội:\n",data.iloc[0]) 
#Lấy dữ liệu 3 hàng đầu tiên
print("\nDữ liệu của Hà Nội, Quảng Ninh và Nam Định:\n",data.iloc[0:3]) 
#Lấy dữ liệu 2 hàng, 2 cột đầu tiên
print("\nDữ liệu dân số và diện tích của Hà Nội và Quảng Ninh:\n",data.iloc[:2,:2])
#Lấy dữ liệu về mật độ dân số của các tỉnh còn lại
print("Mật độ dân số của các tỉnh/thành phố:\n",data.iloc[:,-1])
# Out:
#                  Dân số  Diện tích  population       Mật độ
# Hà Nội          8330830     3358.9     8330830  2480.225669
# Quảng Ninh      1358490     6177.7     1358490   219.902229
# Nam Định        1771000     1668.0     1771000  1061.750600
# Đà Nẵng         1191381     1284.9     1191381   927.216904
# TP.Hồ Chí Minh  9411805     2061.0     9411805  4566.620573
#
# Dữ liệu của thủ đô Hà Nội:
#  Dân số        8.330830e+06
# Diện tích     3.358900e+03
# population    8.330830e+06
# Mật độ        2.480226e+03
# Name: Hà Nội, dtype: float64
#
# Dữ liệu của Hà Nội, Quảng Ninh và Nam Định:
#               Dân số  Diện tích  population       Mật độ
# Hà Nội      8330830     3358.9     8330830  2480.225669
# Quảng Ninh  1358490     6177.7     1358490   219.902229
# Nam Định    1771000     1668.0     1771000  1061.750600
#
# Dữ liệu dân số và diện tích của Hà Nội và Quảng Ninh:
#               Dân số  Diện tích
# Hà Nội      8330830     3358.9
# Quảng Ninh  1358490     6177.7
# ...

# %%
#Lấy dữ liệu dân số và mật độ các tỉnh/TP có diện tích > 2000km2.
print(data.loc[data['Diện tích'] > 2000, ['Dân số', 'Mật độ']])
# Out:
#                  Dân số       Mật độ
# Hà Nội          8330830  2480.225669
# Quảng Ninh      1358490   219.902229
# TP.Hồ Chí Minh  9411805  4566.620573

# %%
print("Diện tích các tỉnh/TP có mật độ < 1000 và dân số > 1 triệu:\n",data.loc[( data['Mật độ']<1000) & (data['Dân số'] > 1000000), ['Diện tích', 'Mật độ'] ])
# Out:
# Diện tích các tỉnh/TP có mật độ < 1000 và dân số > 1 triệu:
#              Diện tích      Mật độ
# Quảng Ninh     6177.7  219.902229
# Đà Nẵng        1284.9  927.216904

# %%
#Sử dụng indexing
print("Indexing:\n", data['Diện tích']) #Slicing
print("Slicing:\n",data['Hà Nội':'Nam Định'])
# Out:
# Indexing:
#  Hà Nội            3358.9
# Quảng Ninh        6177.7
# Nam Định          1668.0
# Đà Nẵng           1284.9
# TP.Hồ Chí Minh    2061.0
# Name: Diện tích, dtype: float64
# Slicing:
#               Dân số  Diện tích  population       Mật độ
# Hà Nội      8330830     3358.9     8330830  2480.225669
# Quảng Ninh  1358490     6177.7     1358490   219.902229
# Nam Định    1771000     1668.0     1771000  1061.750600

# %%
print(data[0:2])
# Out:
#              Dân số  Diện tích  population       Mật độ
# Hà Nội      8330830     3358.9     8330830  2480.225669
# Quảng Ninh  1358490     6177.7     1358490   219.902229

# %%
print(data[data['Dân số']>1000000])
# Out:
#                  Dân số  Diện tích  population       Mật độ
# Hà Nội          8330830     3358.9     8330830  2480.225669
# Quảng Ninh      1358490     6177.7     1358490   219.902229
# Nam Định        1771000     1668.0     1771000  1061.750600
# Đà Nẵng         1191381     1284.9     1191381   927.216904
# TP.Hồ Chí Minh  9411805     2061.0     9411805  4566.620573

# %%
np.random.seed(0)
arr=np.random.randint(10,size=(3,4))
arr
# Out:
# array([[5, 0, 3, 3],
#        [7, 9, 3, 5],
#        [2, 4, 7, 6]])

# %%
arr[0]
# Out:
# array([5, 0, 3, 3])

# %%
arr-arr[0]
# Out:
# array([[ 0,  0,  0,  0],
#        [ 2,  9,  0,  2],
#        [-3,  4,  4,  3]])

# %%
df=pd.DataFrame(arr,columns=['P','Q','M','N'])
print("df:\n",df)
# Out:
# df:
#     P  Q  M  N
# 0  5  0  3  3
# 1  7  9  3  5
# 2  2  4  7  6

# %%
df.iloc[0]
# Out:
# P    5
# Q    0
# M    3
# N    3
# Name: 0, dtype: int64

# %%
df.iloc[0].index
# Out:
# Index(['P', 'Q', 'M', 'N'], dtype='object')

# %%
df.columns
# Out:
# Index(['P', 'Q', 'M', 'N'], dtype='object')

# %%
df.iloc[0].index==df.columns
# Out:
# array([ True,  True,  True,  True])

# %%
df.iloc[0].name
# Out:
# 0

# %%
df
# Out:
#    P  Q  M  N
# 0  5  0  3  3
# 1  7  9  3  5
# 2  2  4  7  6

# %%
df['Q']
# Out:
# 0    0
# 1    9
# 2    4
# Name: Q, dtype: int64

# %%
arr_nan=np.array([1,np.nan,3,4])
print(f"mangr gốc:{arr_nan}")
# Out:
# mangr gốc:[ 1. nan  3.  4.]

# %%
print("____ 6. chuẩn bị DataFrame cho Demo ____")
data={'A':[1.0,2.0,np.nan,4.0],
      'B':[np.nan,6.0,7.0,8.0],
      'C':[9,10,11,12]}
df_demo=pd.DataFrame(data)
print(f"DataFrame gốc(df_demo):\n{df_demo}")
# Out:
# ____ 6. chuẩn bị DataFrame cho Demo ____
# DataFrame gốc(df_demo):
#      A    B   C
# 0  1.0  NaN   9
# 1  2.0  6.0  10
# 2  NaN  7.0  11
# 3  4.0  8.0  12

# %%
print("\n__7.Demo isnull() và lọc__")
mask_na=df_demo.isnull()
print(f"kết quả isnull():\n{mask_na}")
# Out:
# __7.Demo isnull() và lọc__
# kết quả isnull():
#        A      B      C
# 0  False   True  False
# 1  False  False  False
# 2   True  False  False
# 3  False  False  False

# %%
import pandas as pd
index_tuples=[
              ('Hà Nội',2015),('Hà Nội',2020),
              ('Nam Định',2015),('Nam Định',2020),
              ('Thanh Hoá',2015),('Thanh Hoá',2020),
              ('Đà Nẵng',2015),('Đà Nẵng',2020),
              ('Hồ Chí Minh',2015),('Hồ Chí Minh',2020)]
data=[7216000,8246540,
      1850600,1780330,
      3514200,3664940,
      1028800,1169480,
      8146300,9227600]

# %%
vn_pop=pd.Series(data,index=index_tuples)
print("Series sử dụng index bằng tuple(cách thử công):")
vn_pop
# Out:
# Series sử dụng index bằng tuple(cách thử công):
# (Hà Nội, 2015)         7216000
# (Hà Nội, 2020)         8246540
# (Nam Định, 2015)       1850600
# (Nam Định, 2020)       1780330
# (Thanh Hoá, 2015)      3514200
# (Thanh Hoá, 2020)      3664940
# (Đà Nẵng, 2015)        1028800
# (Đà Nẵng, 2020)        1169480
# (Hồ Chí Minh, 2015)    8146300
# (Hồ Chí Minh, 2020)    9227600
# dtype: int64

# %%
vn_pop[('Hà Nội',2015):('Nam Định',2015)]
# Out:
# (Hà Nội, 2015)      7216000
# (Hà Nội, 2020)      8246540
# (Nam Định, 2015)    1850600
# dtype: int64

# %%
vn_pop.index
# Out:
# Index([     ('Hà Nội', 2015),      ('Hà Nội', 2020),    ('Nam Định', 2015),
#           ('Nam Định', 2020),   ('Thanh Hoá', 2015),   ('Thanh Hoá', 2020),
#            ('Đà Nẵng', 2015),     ('Đà Nẵng', 2020), ('Hồ Chí Minh', 2015),
#        ('Hồ Chí Minh', 2020)],
#       dtype='object')

# %%
vn_pop[[i for i in vn_pop.index if i[1]==2020]]
# Out:
# (Hà Nội, 2020)         8246540
# (Nam Định, 2020)       1780330
# (Thanh Hoá, 2020)      3664940
# (Đà Nẵng, 2020)        1169480
# (Hồ Chí Minh, 2020)    9227600
# dtype: int64

# %%
multi_idx=pd.MultiIndex.from_tuples(index_tuples,names=['Tỉnh/TP','Năm'])
multi_idx
# Out:
# MultiIndex([(     'Hà Nội', 2015),
#             (     'Hà Nội', 2020),
#             (   'Nam Định', 2015),
#             (   'Nam Định', 2020),
#             (  'Thanh Hoá', 2015),
#             (  'Thanh Hoá', 2020),
#             (    'Đà Nẵng', 2015),
#             (    'Đà Nẵng', 2020),
#             ('Hồ Chí Minh', 2015),
#             ('Hồ Chí Minh', 2020)],
#            names=['Tỉnh/TP', 'Năm'])

# %%
vn_pop_mul=vn_pop.reindex(multi_idx)
vn_pop_mul
# Out:
# Tỉnh/TP      Năm
# Hà Nội       2015    7216000
#              2020    8246540
# Nam Định     2015    1850600
#              2020    1780330
# Thanh Hoá    2015    3514200
#              2020    3664940
# Đà Nẵng      2015    1028800
#              2020    1169480
# Hồ Chí Minh  2015    8146300
#              2020    9227600
# dtype: int64

# %%
type(vn_pop_mul)
# Out:
# pandas.core.series.Series

# %%
vn_pop_mul[:,2020]
# Out:
# Tỉnh/TP
# Hà Nội         8246540
# Nam Định       1780330
# Thanh Hoá      3664940
# Đà Nẵng        1169480
# Hồ Chí Minh    9227600
# dtype: int64

# %%
vn_pop[:,2020]# bị lỗi vì vn_pop có chỉ mục không phải là đa cấp(multiindex)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 vn_pop[:,2020]
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/series.py:1165, in Series.__getitem__(self, key)
#    1162     key = np.asarray(key, dtype=bool)
#    1163     return self._get_rows_with_mask(key)
# -> 1165 return self._get_with(key)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/series.py:1175, in Series._get_with(self, key)
#    1170     raise TypeError(
#    1171         "Indexing a Series with DataFrame is not "
#    1172         "supported, use the appropriate DataFrame column"
#    1173     )
#    1174 elif isinstance(key, tuple):
# -> 1175     return self._get_values_tuple(key)
#    1177 elif not is_list_like(key):
# ...

# %%
vn_pop_mul
# Out:
# Tỉnh/TP      Năm
# Hà Nội       2015    7216000
#              2020    8246540
# Nam Định     2015    1850600
#              2020    1780330
# Thanh Hoá    2015    3514200
#              2020    3664940
# Đà Nẵng      2015    1028800
#              2020    1169480
# Hồ Chí Minh  2015    8146300
#              2020    9227600
# dtype: int64

# %%
vn_pop_df=vn_pop_mul.unstack('Năm')
print("DataFrame dạng rộng(cột là năm):")
display(vn_pop_df)
# Out:
# DataFrame dạng rộng(cột là năm):
# Năm             2015     2020
# Tỉnh/TP
# Hà Nội       7216000  8246540
# Hồ Chí Minh  8146300  9227600
# Nam Định     1850600  1780330
# Thanh Hoá    3514200  3664940
# Đà Nẵng      1028800  1169480

# %%
type(vn_pop_df)
# Out:
# pandas.core.frame.DataFrame

# %%
print("\nSeries dạng dài (stack lại):")
display(vn_pop_df.stack())
# Out:
# Series dạng dài (stack lại):
# Tỉnh/TP      Năm
# Hà Nội       2015    7216000
#              2020    8246540
# Hồ Chí Minh  2015    8146300
#              2020    9227600
# Nam Định     2015    1850600
#              2020    1780330
# Thanh Hoá    2015    3514200
#              2020    3664940
# Đà Nẵng      2015    1028800
#              2020    1169480
# dtype: int64

# %%
type(vn_pop_df.stack())
# Out:
# pandas.core.series.Series

# %%
vn_pop_df.stack()
# Out:
# Tỉnh/TP      Năm
# Hà Nội       2015    7216000
#              2020    8246540
# Hồ Chí Minh  2015    8146300
#              2020    9227600
# Nam Định     2015    1850600
#              2020    1780330
# Thanh Hoá    2015    3514200
#              2020    3664940
# Đà Nẵng      2015    1028800
#              2020    1169480
# dtype: int64

# %%
vn_pop_df
# Out:
# Năm             2015     2020
# Tỉnh/TP
# Hà Nội       7216000  8246540
# Hồ Chí Minh  8146300  9227600
# Nam Định     1850600  1780330
# Thanh Hoá    3514200  3664940
# Đà Nẵng      1028800  1169480

# %%
co_viec_2015=[3752320,1080750,1512340,512340,4920000]
co_viec_2020=[4042454,1011049,1600000,600000,5200000]
vn_pop_df_expanded=pd.DataFrame({
    ('Tổng dân số',2015):vn_pop_df[2015],
    ('Tổng dân số',2020):vn_pop_df[2020],
    ('Có việc',2015):co_viec_2015,
    ('Có việc',2020): co_viec_2020,
},index=vn_pop_df.index)

# %%
import pandas as pd
sr1 = pd.Series(['Đ','H','K','T'], index=[1,2,3,4])
sr2 = pd.Series(['K','T','C','N'], index=[5,6,7,8])
pd.concat([sr1, sr2])
# Out:
# 1    Đ
# 2    H
# 3    K
# 4    T
# 5    K
# 6    T
# 7    C
# 8    N
# dtype: object

# %%
import pandas as pd
sr1 = pd.Series(['Đ','H','K','T'], index=[1,2,3,4])
sr2 = pd.Series(['K','T','C','N'], index=[5,6,7,8])

# %%
sr1
# Out:
# 1    Đ
# 2    H
# 3    K
# 4    T
# dtype: object

# %%
sr2
# Out:
# 5    K
# 6    T
# 7    C
# 8    N
# dtype: object

# %%
pd.concat([sr1, sr2])
# Out:
# 1    Đ
# 2    H
# 3    K
# 4    T
# 5    K
# 6    T
# 7    C
# 8    N
# dtype: object

# %%
import pandas as pd
A = pd.DataFrame([['A0','B0'],['A1','B1']], columns=['A','B'])
B = pd.DataFrame([['A2','B2'],['A3','B3']], columns=['A','B'])

# %%
A
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1

# %%
B
# Out:
#     A   B
# 0  A2  B2
# 1  A3  B3

# %%
pd.concat([A,B])
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 0  A2  B2
# 1  A3  B3

# %%
print('\nối A và B theo cột (axis=1):')
display(pd.concat([A,B],axis=1))
# Out:
# ối A và B theo cột (axis=1):
#     A   B   A   B
# 0  A0  B0  A2  B2
# 1  A1  B1  A3  B3

# %%
data=[[0,1,0,1],
      [2,1,0,1],
      [1,0,2,0]]
df = pd.DataFrame(data, columns=['A','B','C','D'])
df
# Out:
#    A  B  C  D
# 0  0  1  0  1
# 1  2  1  0  1
# 2  1  0  2  0

# %%
df.sum(axis=0)
# Out:
# A    3
# B    2
# C    2
# D    2
# dtype: int64

# %%
df.sum(axis=1)
# Out:
# 0    2
# 1    4
# 2    3
# dtype: int64

# %%
pd.concat([A, B])
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 0  A2  B2
# 1  A3  B3

# %%
pd.concat([A, B], ignore_index=True)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 3  A3  B3

# %%
print(A)
print(B)
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
#     A   B
# 0  A2  B2
# 1  A3  B3

# %%
pd.concat([A, B])
# Out:
#     A   B
# 0  A0  B0
# 1  A1  B1
# 0  A2  B2
# 1  A3  B3

# %%
try:
    pd.concat([A, B], verify_integrity=True)
except ValueError as e:
    print('Lỗi ValueError:', e)
# Out:
# Lỗi ValueError: Indexes have overlapping values: Index([0, 1], dtype='int64')

# %%
pd.concat([A, B], keys=['Data A', 'Data B'])
# Out:
#            A   B
# Data A 0  A0  B0
#        1  A1  B1
# Data B 0  A2  B2
#        1  A3  B3

# %%
try:
    display(A.append(B))
except Exception as e:
    print('append() không còn hỗ trợ trong Pandas mới:', e)
# Out:
# append() không còn hỗ trợ trong Pandas mới: 'DataFrame' object has no attribute 'append'

# %%
import pandas as pd
df1 = pd.DataFrame({
    'Nhân viên':['Bình','Minh','Lan','Vân'],
    'Phòng/Ban':['Kế toán','Kỹ thuật','Kỹ thuật','HCQT']
})
df2 = pd.DataFrame({
    'Nhân viên':['Bình','Minh','Lan','Vân'],
    'Năm':[2020,2010,2004,2011]
})

# %%
df1
# Out:
#   Nhân viên Phòng/Ban
# 0      Bình   Kế toán
# 1      Minh  Kỹ thuật
# 2       Lan  Kỹ thuật
# 3       Vân      HCQT

# %%
df2
# Out:
#   Nhân viên   Năm
# 0      Bình  2020
# 1      Minh  2010
# 2       Lan  2004
# 3       Vân  2011

# %%
nhanvien=pd.merge(df1, df2)
nhanvien
# Out:
#   Nhân viên Phòng/Ban   Năm
# 0      Bình   Kế toán  2020
# 1      Minh  Kỹ thuật  2010
# 2       Lan  Kỹ thuật  2004
# 3       Vân      HCQT  2011

# %%
#1. DataFrame "Một" (One-side)
quanly = pd.DataFrame({
    'Phòng/Ban':['Kế toán','Kỹ thuật','HCQT'],              #Cột khóa chung để gộp 'Phòng/Ban'
    'Quản lý':['Ly','Cường','Minh']
})
quanly
# Out:
#   Phòng/Ban Quản lý
# 0   Kế toán      Ly
# 1  Kỹ thuật   Cường
# 2      HCQT    Minh

# %%
nhanvien
# Out:
#   Nhân viên Phòng/Ban   Năm
# 0      Bình   Kế toán  2020
# 1      Minh  Kỹ thuật  2010
# 2       Lan  Kỹ thuật  2004
# 3       Vân      HCQT  2011

# %%
quanly_to_nhanvien_1_N = pd.merge(nhanvien, quanly, on='Phòng/Ban')
quanly_to_nhanvien_1_N
# Out:
#   Nhân viên Phòng/Ban   Năm Quản lý
# 0      Bình   Kế toán  2020      Ly
# 1      Minh  Kỹ thuật  2010   Cường
# 2       Lan  Kỹ thuật  2004   Cường
# 3       Vân      HCQT  2011    Minh

# %%
#1. DataFrame nhanvien: 'Nhiều' (Many-side)
#Cột khóa 'Phòng/Ban' có giá trị 'Kỹ thuật' lặp 2 lần (Duplicate), mỗi phòng/ban có nhiều nhân viên
nhanvien
# Out:
#   Nhân viên Phòng/Ban   Năm
# 0      Bình   Kế toán  2020
# 1      Minh  Kỹ thuật  2010
# 2       Lan  Kỹ thuật  2004
# 3       Vân      HCQT  2011

# %%
#2. Dataframe: quanly: 'Một' (One-side)
#Cột khóa chung 'Phòng/Ban chỉ có giá trị duy nhất (mỗi phòng duy nhất 1 quản lý)
quanly
# Out:
#   Phòng/Ban Quản lý
# 0   Kế toán      Ly
# 1  Kỹ thuật   Cường
# 2      HCQT    Minh

# %%
#3. Kết nối Many-to_One giữa dataframe nhanvien và dataFrame quanly
nhan_vien_to_quanly_N_1=pd.merge(nhanvien,quanly)
nhan_vien_to_quanly_N_1
# Out:
#   Nhân viên Phòng/Ban   Năm Quản lý
# 0      Bình   Kế toán  2020      Ly
# 1      Minh  Kỹ thuật  2010   Cường
# 2       Lan  Kỹ thuật  2004   Cường
# 3       Vân      HCQT  2011    Minh

# %%
nv_salary = pd.DataFrame({
    'Name':['Bình','Minh','Lan','Vân'],
    'Lương':[18,20,22,16]
})
m1 = pd.merge(df1, df2, on='Nhân viên')

m1.head()
# Out:
#   Nhân viên Phòng/Ban   Năm
# 0      Bình   Kế toán  2020
# 1      Minh  Kỹ thuật  2010
# 2       Lan  Kỹ thuật  2004
# 3       Vân      HCQT  2011

# %%
df1
# Out:
#   Nhân viên Phòng/Ban
# 0      Bình   Kế toán
# 1      Minh  Kỹ thuật
# 2       Lan  Kỹ thuật
# 3       Vân      HCQT

# %%
nv_salary
# Out:
#    Name  Lương
# 0  Bình     18
# 1  Minh     20
# 2   Lan     22
# 3   Vân     16

# %%
m2 = pd.merge(df1, nv_salary, left_on='Nhân viên', right_on='Name')  #Ghép khóa khác tên
m2.head()
# Out:
#   Nhân viên Phòng/Ban  Name  Lương
# 0      Bình   Kế toán  Bình     18
# 1      Minh  Kỹ thuật  Minh     20
# 2       Lan  Kỹ thuật   Lan     22
# 3       Vân      HCQT   Vân     16

# %%
m2_drop = m2.drop(columns=['Name'])
m2_drop.head()
# Out:
#   Nhân viên Phòng/Ban  Lương
# 0      Bình   Kế toán     18
# 1      Minh  Kỹ thuật     20
# 2       Lan  Kỹ thuật     22
# 3       Vân      HCQT     16

# %%
df1_idx = df1.set_index('Nhân viên')
df2_idx = df2.set_index('Nhân viên')

# %%
df1_idx
# Out:
#           Phòng/Ban
# Nhân viên
# Bình        Kế toán
# Minh       Kỹ thuật
# Lan        Kỹ thuật
# Vân            HCQT

# %%
df2_idx
# Out:
#             Năm
# Nhân viên
# Bình       2020
# Minh       2010
# Lan        2004
# Vân        2011

# %%
m_idx = pd.merge(df1_idx, df2_idx, left_index=True, right_index=True)
m_idx
# Out:
#           Phòng/Ban   Năm
# Nhân viên
# Bình        Kế toán  2020
# Minh       Kỹ thuật  2010
# Lan        Kỹ thuật  2004
# Vân            HCQT  2011

# %%
j_idx = df1_idx.join(df2_idx)  # tương đương left join theo Index
j_idx.head()
# Out:
#           Phòng/Ban   Năm
# Nhân viên
# Bình        Kế toán  2020
# Minh       Kỹ thuật  2010
# Lan        Kỹ thuật  2004
# Vân            HCQT  2011

# %%
df2_idx
# Out:
#             Năm
# Nhân viên
# Bình       2020
# Minh       2010
# Lan        2004
# Vân        2011

# %%
nv_salary
# Out:
#    Name  Lương
# 0  Bình     18
# 1  Minh     20
# 2   Lan     22
# 3   Vân     16

# %%
mixed = pd.merge(df2_idx, nv_salary, left_index=True, right_on='Name')
mixed.head()
# Out:
#     Năm  Name  Lương
# 0  2020  Bình     18
# 1  2010  Minh     20
# 2  2004   Lan     22
# 3  2011   Vân     16

# %%
nv_location = pd.DataFrame({
    'Nhân viên':['Bình','Minh','Lan','Vân'],
    'Nơi sinh':['Hà Nội','Hải Phòng','Nam Định','Đà Nẵng']
})
nv_age = pd.DataFrame({
    'Nhân viên':['Bình','Lan','Vân','Hà'],
    'Tuổi':[28,25,30,27]
})

# %%
nv_location
# Out:
#   Nhân viên   Nơi sinh
# 0      Bình     Hà Nội
# 1      Minh  Hải Phòng
# 2       Lan   Nam Định
# 3       Vân    Đà Nẵng

# %%
# !python.exe -m pip install --upgrade pip
# Out:
# zsh:1: command not found: python.exe

# %%
# !pip install seaborn

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.13.2'

# %%
pivot_age = pd.pivot_table(
    titanic_data,
    values="age",
    index="sex",
    columns="class",
    aggfunc="mean"
)
pivot_age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 2
#       1 pivot_age = pd.pivot_table(
# ----> 2     titanic_data,
#       3     values="age",
#       4     index="sex",
#       5     columns="class",
#       6     aggfunc="mean"
#       7 )
#       8 pivot_age
#
# NameError: name 'titanic_data' is not defined

# %%
titanic_data.groupby("sex")["age"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 titanic_data.groupby("sex")["age"].mean()
#
# NameError: name 'titanic_data' is not defined

# %%
import pandas as pd
import seaborn as sns

# Nạp dữ liệu Titanic
titanic_data = sns.load_dataset("titanic")

# Hiển thị một số mẫu dữ liệu
titanic_data.head()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.13.2
# Summary: Statistical data visualization
# Home-page:
# Author:
# Author-email: Michael Waskom <mwaskom@gmail.com>
# License:
# Location: /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages
# Requires: matplotlib, numpy, pandas
# Required-by:

# %%
import pandas as pd
import seaborn as sns

# Nạp dữ liệu Titanic
titanic_data = sns.load_dataset("titanic")

# Hiển thị một số mẫu dữ liệu
titanic_data.head()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/urllib/request.py:1319, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1318 try:
# -> 1319     h.request(req.get_method(), req.selector, req.data, headers,
#    1320               encode_chunked=req.has_header('Transfer-encoding'))
#    1321 except OSError as err: # timeout error
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# ...

# %%
titanic_data.groupby("sex")["age"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 titanic_data.groupby("sex")["age"].mean()
#
# NameError: name 'titanic_data' is not defined

# %%
import pandas as pd
import seaborn as sns

# %%
import pandas as pd
import seaborn as sns

titanic_data = pd.read_csv("titanic.csv")
titanic_data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[61], line 4
#       1 import pandas as pd
#       2 import seaborn as sns
# ----> 4 titanic_data = pd.read_csv("titanic.csv")
#       5 titanic_data.head()
#
# ...

# %%
SSLCertVerificationError
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 SSLCertVerificationError
#
# NameError: name 'SSLCertVerificationError' is not defined

# %%
import pandas as pd
import seaborn as sns

# Nạp dữ liệu Titanic
titanic_data = sns.load_dataset("titanic")

# Hiển thị một số mẫu dữ liệu
titanic_data.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
